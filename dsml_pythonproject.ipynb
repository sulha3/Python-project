# %%
import pandas as pd

# %% [markdown]
# # read data

# %%
data=pd.read_csv("myexcel.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # cleaning data

# %% [markdown]
# ## missing values

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
x=data['Salary'].mean()
x
# Out:
# 4833969.545861297

# %%
data['Salary'].fillna(x,inplace=True)
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
data=data.drop(['College'] ,axis='columns')
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#            Salary
# 0    7.730337e+06
# 1    6.796117e+06
# 2    4.833970e+06
# ...

# %% [markdown]
# ##  duplicated data

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#            Salary
# 0    7.730337e+06
# 1    6.796117e+06
# 2    4.833970e+06
# ...

# %% [markdown]
# ## incorrect data

# %%
import numpy as np

# %%
arr=np.random.randint(150,180,len(data))
arr
# Out:
# array([179, 157, 156, 179, 170, 175, 176, 164, 152, 163, 173, 154, 177,
#        155, 172, 155, 165, 153, 164, 174, 178, 174, 171, 165, 161, 158,
#        171, 162, 171, 153, 165, 165, 175, 175, 160, 168, 164, 174, 155,
#        173, 178, 159, 155, 173, 152, 158, 159, 160, 170, 178, 178, 161,
#        179, 170, 159, 159, 173, 169, 164, 173, 176, 170, 175, 153, 160,
#        166, 151, 177, 177, 174, 169, 179, 151, 174, 158, 172, 160, 150,
#        177, 165, 172, 174, 168, 160, 163, 170, 171, 161, 165, 172, 162,
#        171, 173, 154, 150, 155, 175, 179, 168, 158, 152, 163, 154, 165,
#        150, 158, 174, 154, 161, 157, 155, 161, 171, 167, 168, 176, 154,
#        155, 163, 154, 169, 178, 174, 159, 178, 157, 152, 172, 153, 157,
#        168, 178, 173, 165, 171, 177, 173, 172, 171, 159, 165, 167, 167,
#        174, 163, 169, 166, 173, 176, 161, 179, 151, 163, 176, 166, 157,
#        178, 170, 177, 167, 176, 173, 154, 178, 160, 166, 152, 160, 154,
# ...

# %%
data['Height']=arr
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     179     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     157     235
# 2     John Holland  Boston Celtics      30       SG   27     156     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     179     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     150     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     162     256
# 456    Jeff Withey       Utah Jazz      24        C   26     172     231
# 457       Priyanka       Utah Jazz      34        C   25     174     231
#
#            Salary
# 0    7.730337e+06
# 1    6.796117e+06
# 2    4.833970e+06
# ...

# %% [markdown]
# ### How many are there in each team and the percentage splitting with respect to the toatal employees

# %%
team=data['Team'].value_counts()
team
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
percentage_spltng=(team/len(data))*100
percentage_spltng
# Out:
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# Philadelphia 76ers        3.275109
# ...

# %% [markdown]
# ### seggregate the employees w.r.t different position

# %%
empyee=data.groupby("Position")["Name"].unique()
empyee
# Out:
# Position
# C     [Kelly Olynyk, Jared Sullinger, Tyler Zeller, ...
# PF    [Jonas Jerebko, Amir Johnson, Jordan Mickey, C...
# PG    [Avery Bradley, Terry Rozier, Marcus Smart, Is...
# SF    [Jae Crowder, Thanasis Antetokounmpo, Carmelo ...
# SG    [John Holland, R.J. Hunter, Evan Turner, James...
# Name: Name, dtype: object

# %% [markdown]
# ### find from  which group mpst of the employees belongs to

# %%
age=data['Age'].value_counts()
age
# Out:
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: Age, dtype: int64

# %% [markdown]
# ##### most of the employees age is 24

# %% [markdown]
# ### find out under which team and position,spending in terms of salary is high

# %%
sp=data.groupby(['Team','Position'])['Salary'].sum()
sp
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %%
max=sp.idxmax()
max
# Out:
# ('Los Angeles Lakers', 'SF')

# %% [markdown]
# ### find if there is any correlation between age and salary

# %%
correlation=data['Age'].corr(data['Salary'])
print(" correlation", correlation)
# Out:
#  correlation 0.2111695491768639

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['Age'],data['Salary'], color="green")
plt.title('correlation between age and salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.legend
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data1=data.drop(["Team","Name","Number","Position","Weight","Height"],axis="columns")
data1
# Out:
#      Age        Salary
# 0     25  7.730337e+06
# 1     25  6.796117e+06
# 2     27  4.833970e+06
# 3     22  1.148640e+06
# 4     29  5.000000e+06
# ..   ...           ...
# 453   26  2.433333e+06
# 454   24  9.000000e+05
# 455   26  2.900000e+06
# 456   26  9.472760e+05
# 457   25  9.472760e+05
#
# [458 rows x 2 columns]

# %%
corr=data1.corr()
corr
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title("correlation between age and salary")
plt.show()
